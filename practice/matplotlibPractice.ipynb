# %% [markdown]
# # MatplotLib Tutorial
# Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy. It provides an object-oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, Qt, or GTK+.
#
# Some of the major Pros of Matplotlib are:
#
# Generally easy to get started for simple plots
# Support for custom labels and texts
# Great control of every element in a figure
# High-quality output in many formats
# Very customizable in general

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline #need not right plt.show()

# %%
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
#plotting using matplotlib
plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Testgraph.png')

# %%
y=x*x

# %%
plt.plot(x,y,'r*--')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D Diagram')
# Out:
# Text(0.5, 1.0, '2D Diagram')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'ro')
plt.subplot(2,2,2)
plt.plot(x,y,'g--')
plt.subplot(2,2,3)
plt.plot(x,y,'b*--')
plt.subplot(2,2,4)
plt.plot(x,y,'g')

# %%
np.pi
# Out:
# 3.141592653589793

# %%
x = np.arange(0, 4 * np.pi, 0.1)
y = np.sin(x)
plt.title('Sine wave form')
plt.plot(x,y)

# %%
x = np.arange(0, 5 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.subplot(2,1,1)
plt.plot(x,y_sin)
plt.title('Sine')

plt.subplot(2,1,2)
plt.plot(x,y_cos)
plt.title('Cosine')
# Out:
# Text(0.5, 1.0, 'Cosine')

# %%
#bar plot 
x=[2,3,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]

plt.bar(x,y)
plt.bar(x2,y2,color='g')
plt.title('Bar plot')
plt.xlabel('X axis')
plt.ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a)
plt.title('histogram')
# Out:
# Text(0.5, 1.0, 'histogram')

# %%
data = [np.random.normal(0, std, 100) for std in range(1,4)]
plt.boxplot(data, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fe9d63aedc0>,
#   <matplotlib.lines.Line2D at 0x7fe9d63ae1f0>,
#   <matplotlib.lines.Line2D at 0x7fe9d53d1070>,
#   <matplotlib.lines.Line2D at 0x7fe9d62b2550>,
#   <matplotlib.lines.Line2D at 0x7fe9d53c94c0>,
#   <matplotlib.lines.Line2D at 0x7fe9d53c9280>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fe9d6f44040>,
#   <matplotlib.lines.Line2D at 0x7fe9d54feb20>,
#   <matplotlib.lines.Line2D at 0x7fe9d7350a00>,
#   <matplotlib.lines.Line2D at 0x7fe9d6388f70>,
#   <matplotlib.lines.Line2D at 0x7fe9d53c98e0>,
#   <matplotlib.lines.Line2D at 0x7fe9d5501e20>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x7fe9d6225250>,
#   <matplotlib.patches.PathPatch at 0x7fe9d54fe940>,
#   <matplotlib.patches.PathPatch at 0x7fe9d55df460>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fe9d54fe0a0>,
#   <matplotlib.lines.Line2D at 0x7fe9d6db8f10>,
#   <matplotlib.lines.Line2D at 0x7fe9d5501580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fe9d54fec70>,
#   <matplotlib.lines.Line2D at 0x7fe9d6db8be0>,
#   <matplotlib.lines.Line2D at 0x7fe9d522c880>],
#  'means': []}

# %%
data
# Out:
# [array([-1.05425025, -0.34900785,  1.43745037,  0.24866238,  1.23927426,
#          1.33370277, -1.35786341, -0.35372958, -0.56637248, -0.8981966 ,
#         -1.51242791,  0.4552827 ,  1.31303022,  0.63187823,  0.97490421,
#          1.38368615,  1.54888724, -1.00902128,  0.06849882,  0.62780068,
#         -0.50987868,  2.77289516,  1.11713956,  3.23805641,  0.01152296]),
#  array([ 3.513353  ,  5.13137133,  2.10734442, -0.05204475, -0.19238922,
#         -2.84424412, -1.93677183, -5.92385374,  3.56007908,  1.05278892,
#         -6.07220972, -0.44202214, -2.82383999,  3.39068502, -2.91131274,
#          4.87001493, -0.43520913, -4.34461345,  1.01607794, -2.9230334 ,
#         -3.34160776, -3.6609723 , -0.73806712,  0.04346534,  3.80426208,
#         -1.74174447,  1.83099112, -0.2465114 ,  2.61526695,  2.51683097,
#          0.82563507, -0.05078684,  2.86456483, -0.00898136,  2.12060003,
#         -0.22542571, -2.50897772,  4.7459508 ,  1.70669989,  0.37905801,
#         -1.66217285,  1.95560149,  0.33839546,  0.38831268, -4.90665734,
#         -3.31007745, -2.55696456, -1.64435711,  2.72885877,  1.53120942,
#          1.1348301 ,  2.40085513,  3.41878137,  4.68246145, -3.5633442 ,
#          1.93425156, -4.55325531,  1.82984894, -3.4449657 , -3.5000889 ,
#          2.18103828,  2.24887617,  2.4710087 ,  0.49777387,  3.77708528,
#          5.11975476,  2.44521727, -0.71104194, -1.79950975, -0.32254577,
#          0.84791982,  0.2293094 ,  0.08021791, -0.28899184,  0.09197014,
#          5.9928498 , -1.99767302,  0.17827564, -0.98651052, -3.69035916,
#         -4.15814214, -2.02344776,  0.72145127, -0.59513807,  1.41155216,
#         -0.63421336,  3.34044026, -4.07837682, -4.32340452, -2.24573273,
#         -2.65621593, -2.3891027 ,  0.34733266, -1.52644888, -0.47126414,
#         -0.34242632,  2.40245217, -8.16203603, -0.64369881, -0.32038534])]

# %%
labels = 'Python', 'C', 'Ruby', 'Java'
sizes = [215,130,245,210]
colors = ['gold', 'yellowgreen', 'lightcoral','lightskyblue']
explode = (0.2,0,0.1,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow='True')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe9d44ae130>,
#   <matplotlib.patches.Wedge at 0x7fe9d44ae730>,
#   <matplotlib.patches.Wedge at 0x7fe9d4518820>,
#   <matplotlib.patches.Wedge at 0x7fe9d450bd30>],
#  [Text(0.8635281328915398, 0.9717608572611122, 'Python'),
#   Text(-0.64656382751384, 0.8899186574910392, 'C'),
#   Text(-1.0352812290863453, -0.606788906211597, 'Ruby'),
#   Text(0.7466808503372186, -0.8077547324155323, 'Java')],
#  [Text(0.5314019279332552, 0.5980066813914535, '26.9%'),
#   Text(-0.35267117864391273, 0.485410176813294, '16.2%'),
#   Text(-0.603914050300368, -0.3539601952900982, '30.6%'),
#   Text(0.4072804638203011, -0.4405934904084721, '26.2%')])
